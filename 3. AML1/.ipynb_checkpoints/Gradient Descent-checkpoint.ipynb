# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_df = pd.read_csv('data/bike-sharing-simple.csv')

# %%
def rmse(y, y_pred):
    return np.sqrt(np.mean(np.square(y - y_pred)))

# %%
x = data_df.temp.values
y = data_df.users.values

# %%
# Initialization
lr = .1 # learning rate
a, b = 0, 0 # initial a,b values
n_steps = 1000# number of iterations

log_rmse = []

# n_steps iterations
for step in range(n_steps):
    # Predictions with the current a,b values
    y_pred = a*x + b

    # Compute the error vector
    error = y - y_pred

    # Partial derivative with respect to a
    a_grad = -2*np.mean(x*error)

    # Partial derivative with respect to b
    b_grad = -2*np.mean(error)

    # Update a and b
    a -= lr*a_grad
    b -= lr*b_grad
    
    # RMSE error
    log_rmse.append(rmse(y, y_pred))

# %%
sns.set()
plt.plot(log_rmse, label='learning rate: {}'.format(lr))
plt.title('RMSE after {} steps is {:.6f}'.format(n_steps, log_rmse[-1]))
plt.xlabel("time step")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
# OLS solution with polyfit()
a_polyfit, b_polyfit = np.polyfit(x, y, 1)

# Optimal parameters vs. ones obtained with GD
print('Polyfit (a, b)=({:.2f}, {:.2f})'.format(a_polyfit, b_polyfit))
# Prints: (a, b)=(1495.60, -94.61)
print('Gradient descent (a, b)=({:.2f}, {:.2f})'.format(a, b))
# Prints: (a, b)=(1133.56, 98.91)
# Out:
# Polyfit (a, b)=(1495.60, -94.61)
# Gradient descent (a, b)=(1491.23, -92.27)

# %% [markdown]
# ### Stochastic and mini-batch variants

# %%
# Predictions with the current a,b values
y_pred = a*x + b

# Compute the error vector
error = y - y_pred

# Partial derivative with respect to a
a_grad = -2*np.mean(x*error)

# Partial derivative with respect to b
b_grad = -2*np.mean(error)

# Print shape
print('y_pred:', y_pred.shape) # (302,)
print('error:', error.shape) # (302,)
print('a_grad:', a_grad.shape) # ()
print('b grad:', b_grad.shape) # ()
# Out:
# y_pred: (302,)
# error: (302,)
# a_grad: ()
# b grad: ()

# %% [markdown]
# ### Rescaling

# %%
data_df = pd.read_csv('data/bike-sharing-simple.csv')

# %%
# Create x/y arrays
x = 47*data_df.temp.values - 8 # Degrees Celsius
y = data_df.users.values

# %%
# Initialization
lr = .1 # learning rate
a, b = 0, 0 # initial a,b values
n_steps = 100# number of iterations

log_rmse = []

# n_steps iterations
for step in range(n_steps):
    # Predictions with the current a,b values
    y_pred = a*x + b

    # Compute the error vector
    error = y - y_pred

    # Partial derivative with respect to a
    a_grad = -2*np.mean(x*error)

    # Partial derivative with respect to b
    b_grad = -2*np.mean(error)

    # Update a and b
    a -= lr*a_grad
    b -= lr*b_grad
    
    # RMSE error
    log_rmse.append(rmse(y, y_pred))
# Out:
# C:\Users\jisnard.2015-JISNARD\Anaconda3\envs\exts-aml1\lib\site-packages\numpy\core\_methods.py:70: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)
# C:\Users\jisnard.2015-JISNARD\Anaconda3\envs\exts-aml1\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in square

# %%
plt.plot(log_rmse, label='learning rate: {}'.format(lr))
plt.title('RMSE after {} steps is {}'.format(n_steps, log_rmse[-1]))
plt.xlabel("time step")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
log_rmse[-1]
# Out:
# inf

# %%
# Create x/y arrays
x = data_df.temp.values
y = data_df.users.values

# %%
# Initialization
lr = 0.7
a, b = 0, 0
n_steps = 400

# Gradient descent
log_a = [a]
log_b = [b]

for step in range(n_steps):
    # Compute partial derivatives
    y_pred = a*x + b
    error = y - y_pred
    a_grad = -2*np.mean(x*error)
    b_grad = -2*np.mean(error)

    # Update parameters
    a -= lr*a_grad
    b -= lr*b_grad

    # Log a, b values
    log_a.append(a)
    log_b.append(b)

# %%
# Visualize steps
plt.plot(log_a, log_b)
plt.xlabel('parameter a')
plt.ylabel('parameter b')
plt.show()

# %%
def visualize_steps(log_a, log_b, x, y):
    # Define a grid of a,b parameters
    min_ab = min(min(log_a), min(log_b))
    max_ab = max(max(log_a), max(log_b))

    d = max_ab - min_ab
    min_ab -= d * 0.1
    max_ab += d * 0.1

    a = np.linspace(min_ab, max_ab, num=40)
    b = np.linspace(min_ab, max_ab, num=40)
    a_grid, b_grid = np.meshgrid(a, b)

    # Compute the RMSE score for each a,b pair on that grid
    rmse_grid = np.zeros_like(a_grid)

    for i in range(40):
        for j in range(40):
            a, b = a_grid[i, j], b_grid[i, j]
            rmse_grid[i, j] = rmse(a*x+b, y)

    # RMSE surface
    plt.gca().set_aspect('equal', adjustable='box')
    plt.contourf(a_grid, b_grid, rmse_grid, 20, cmap=plt.cm.coolwarm)
    plt.colorbar(label='RMSE')

    # Plot the GD steps
    plt.plot(log_a, log_b, c='#00abe9')
    plt.scatter(log_a, log_b, c='#00abe9')

    # Set titles and labels
    plt.xlabel('parameter a')
    plt.ylabel('parameter b')

    plt.xlim(min_ab, max_ab)
    plt.ylim(min_ab, max_ab)
    plt.show()

# %%
# Plot the error surface
visualize_steps(log_a, log_b, x, y)

# %%
from sklearn.preprocessing import scale

# Standardize x
x_standardized = scale(x)

print('Mean:', x_standardized.mean())
# Prints: -7.05837154729e-17

print('Standard deviation:', x_standardized.std())
# Prints: 1.0
# Out:
# Mean: -7.058371547285764e-17
# Standard deviation: 1.0

# %%
# Initialization
lr = 0.7
a, b = 0, 0
n_steps = 400

# Gradient descent
log_a = [a]
log_b = [b]

for step in range(n_steps):
    # Compute partial derivatives
    y_pred = a*x_standardized + b
    error = y - y_pred
    a_grad = -2*np.mean(x_standardized*error)
    b_grad = -2*np.mean(error)

    # Update parameters
    a -= lr*a_grad
    b -= lr*b_grad

    # Log a, b values
    log_a.append(a)
    log_b.append(b)

# %%
visualize_steps(log_a, log_b, x_standardized, y)
